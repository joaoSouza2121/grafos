# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoSouza2121/grafos/blob/main/Comunidades_E_Cliques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color="green">Grafos</font>
#
# Comunidades e Cliques

# %%
install.packages("igraph")
library(igraph)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %% [markdown]
# # Dados

# %%
grafo8 = read_graph("Grafo.graphml", format = c("graphml"))
grafo8 = as.undirected(grafo8)

# %% [markdown]
# #<font color="brown">Comunidades</font>

# %%
#detecta comunidades
comun = cluster_edge_betweenness(grafo8)
#visualiza
comun
#cada vértice para qual comunidade pertecen
comun$membership
#impressão usando cor para comunidade
plot(grafo8, vertex.color = comun$membership)
# Out:
# Warning message in cluster_edge_betweenness(grafo8):
# “At community.c:460 :Membership vector will be selected based on the lowest modularity score.”
# Warning message in cluster_edge_betweenness(grafo8):
# “At community.c:467 :Modularity calculation with weighted edge betweenness community detection might not make sense -- modularity treats edge weights as similarities while edge betwenness treats them as distances”
# IGRAPH clustering edge betweenness, groups: 22, mod: 0.19
# + groups:
#   $`1`
#   [1]  1  4 14 30 37 46 50
#
#   $`2`
#    [1]  2  6 15 22 25 31 41 42 44 45 49 51 53
#
#   $`3`
#   [1]  3 11 18 23 29 36 38 39
#
#   $`4`
#   + ... omitted several groups/vertices
#  [1]  1  2  3  1  4  2  5  6  7  8  3  9 10  1  2  5 11  3  5 12 13  2  3  4  2
# [26] 14 15 16  3  1  2 17 15 18 19  3  1  3  3 20  2  2 11  2  2  1 21 22  2  1
# [51]  2  5  2
# Plot with title “”

# %% [markdown]
# Grafo Dist

# %%
dist = graph(edges=c("A","C","A","B","B","E","B","F","C","D","G","H","D","H","E","H","F","G"),directed=TRUE)

# %%
comun = cluster_edge_betweenness(dist)
comun
comun$membership

plot(dist, vertex.color = comun$membership, edge.color="gray")
# Out:
# IGRAPH clustering edge betweenness, groups: 3, mod: 0.18
# + groups:
#   $`1`
#   [1] "A" "C"
#
#   $`2`
#   [1] "B" "F"
#
#   $`3`
#   [1] "E" "D" "G" "H"
# [1] 1 1 2 3 2 3 3 3
# Plot with title “”

# %% [markdown]
# #<font color="orange">Detecção de Cliques</font>

# %%
#min é número minimo de membros
cli = cliques(as.undirected(grafo8), min=4)
length(cli)
cli
# Out:
# [1] 17
# [[1]]
# + 4/53 vertices, from e2a06ff:
# [1]  1  4 14 46
#
# [[2]]
# + 4/53 vertices, from e2a06ff:
# [1] 14 15 46 50
#
# [[3]]
# + 4/53 vertices, from e2a06ff:
# [1] 22 41 45 49
#
# [[4]]
# + 4/53 vertices, from e2a06ff:
# [1] 15 22 45 49
#
# [[5]]
# + 4/53 vertices, from e2a06ff:
# [1] 14 30 46 50
#
# [[6]]
# + 4/53 vertices, from e2a06ff:
# [1]  1 14 30 46
#
# [[7]]
# + 4/53 vertices, from e2a06ff:
# [1]  2 15 25 51
#
# [[8]]
# + 4/53 vertices, from e2a06ff:
# [1] 15 25 38 49
#
# [[9]]
# + 4/53 vertices, from e2a06ff:
# [1] 18 23 38 39
#
# [[10]]
# + 4/53 vertices, from e2a06ff:
# [1]  4 14 23 46
#
# [[11]]
# + 4/53 vertices, from e2a06ff:
# [1]  5 14 15 23
#
# [[12]]
# + 4/53 vertices, from e2a06ff:
# [1] 15 23 43 46
#
# [[13]]
# + 4/53 vertices, from e2a06ff:
# [1] 14 15 23 46
#
# [[14]]
# + 4/53 vertices, from e2a06ff:
# [1] 11 15 38 49
#
# [[15]]
# + 4/53 vertices, from e2a06ff:
# [1] 11 15 22 49
#
# [[16]]
# + 4/53 vertices, from e2a06ff:
# [1]  5  6 14 15
#
# [[17]]
# + 4/53 vertices, from e2a06ff:
# [1]  2  6 15 22
