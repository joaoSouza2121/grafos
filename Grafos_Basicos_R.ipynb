# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoSouza2121/grafos/blob/main/Grafos_Basicos_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color="Khaki">Estudando a Teoria dos Grafos</font>

# %%
install.packages("igraph")
library(igraph)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %% [markdown]
# Grafo direcionado, arestas por pares

# %%
grafo1 = graph(edges=c(1,2,3,4))
plot(grafo1)
# Out:
# Plot with title “”

# %% [markdown]
# Grafo conexo

# %%
grafo2 = graph(edges=c(1,2,2,3,3,4,4,1))
plot(grafo2)
# Out:
# Plot with title “”

# %% [markdown]
# Arestas nas duas direções

# %%
grafo2 = graph(edges=c(1,2,2,3,3,4,4,1,1,4,4,3,3,2,2,1))
plot(grafo2)
# Out:
# Plot with title “”

# %% [markdown]
# Laço

# %%
grafo3 = graph(edges=c(1,2,2,3,3,4,4,1,1,1))
plot(grafo3)
# Out:
# Plot with title “”

# %% [markdown]
# Literais, incidência na direção do +
#
# 1-+2 = segue na direção do 2
#
# 3++4 = duas direções

# %%
grafo8 = graph_from_literal(1-+2,2-+3,3++4,4+-1)
plot(grafo8)
# Out:
# Plot with title “”

# %% [markdown]
# Não direcionado com Literais

# %%
grafo8 = graph_from_literal(1-2,2-3,3-4,4-1)
plot(grafo8)
# Out:
# Plot with title “”

# %% [markdown]
# Grafo desconexo, isolado, -> grau zero

# %%
grafo8 = graph_from_literal(1-2-3-4-1,5)
plot(grafo8)
# Out:
# Plot with title “”

# %% [markdown]
# Objeto Igraph
#
# D--- 4 4 --    números são as dimensões de vértices e arestas
#
# 1->2 2->3 3->4 4->1   estrutura do grafo
#
# D/U - direcionado / não direcionado
#
# N nome do grafo
#
# W grafo ponderado (peso nas arestas)
#
# B Tipo do grafo

# %%
grafo2 = graph(edges=c(1,2,2,3,3,4,4,1))
plot(grafo2)
# Out:
# Plot with title “”

# %%
grafo2
# Out:
# IGRAPH 3b67d44 D--- 4 4 --
# + edges from 3b67d44:
# [1] 1->2 2->3 3->4 4->1

# %% [markdown]
# Grafo não direcionado
# U para não direcionado

# %%
grafo3 = graph(edges=c(1,2,2,3,3,4,4,1),directed=F )
plot(grafo3)
# Out:
# Plot with title “”

# %%
grafo3
# Out:
# IGRAPH 2a65920 U--- 4 4 --
# + edges from 2a65920:
# [1] 1--2 2--3 3--4 1--4

# %% [markdown]
# #Elementos Isolados
# Ele completa até o número de n gerando elementos isolados

# %%
grafo4 = graph(edges=c(1,2,2,3,3,4,4,1),directed=F, n=10 )
plot(grafo4)
# Out:
# Plot with title “”

# %% [markdown]
# Vértices Nomeados

# %%
grafo5 <- graph(edges= c("A", "B", "B", "C", "C", "D","D", "E","E","A","A","C","C","B")) 
plot(grafo5)
# Out:
# Plot with title “”

# %% [markdown]
# Outra forma de criar grafos isolados

# %%
grafo6 <- graph(edges= c("A", "B", "B", "C", "C", "D","D", "E","E","A","A","C","C","B"), isolates=c("F","G"))
plot(grafo6)
# Out:
# Plot with title “”

# %% [markdown]
# #matriz adjacente

# %%
grafo6[]
#linha 1
grafo6[1,]
#coluna 1
grafo6[,2]
#nomes dos vértices
V(grafo6)$name
# Out:
# 7 x 7 sparse Matrix of class "dgCMatrix"
#   A B C D E F G
# A . 1 1 . . . .
# B . . 1 . . . .
# C . 1 . 1 . . .
# D . . . . 1 . .
# E 1 . . . . . .
# F . . . . . . .
# G . . . . . . .
# A B C D E F G
# 0 1 1 0 0 0 0
# A B C D E F G
# 1 0 1 0 0 0 0
# [1] "A" "B" "C" "D" "E" "F" "G"

# %% [markdown]
# Outros atributos

# %%
grafo7 <- graph(edges= c("john", "ana", "lara", "vitoria", "john", "lara","john", "lara"))
plot(grafo7)
#pesos aos vértices como atributo
V(grafo7)$Peso = c(40,30,30,25)
#ler atributos, temos name e peso. Nome é padrão
vertex_attr(grafo7)
#atributos para arestas
E(grafo7)$TipoAmizade = c("Amigo","Inimigo","Inimigo","Amigo")
#mostra todos
edge_attr(grafo7)
#mostra atributo pelo nome
edge_attr(grafo7)$TipoAmizade
vertex_attr(grafo7)$Peso
#weight é atributo padrão
E(grafo7)$weight = c(1,2,1,3)
grafo7
#Tipo do grafo, agora temos os 4 simbolos preenchidos
V(grafo7)$type ="Humanos"
grafo7
# Out:
# $name
# [1] "john"    "ana"     "lara"    "vitoria"
#
# $Peso
# [1] 40 30 30 25
# $TipoAmizade
# [1] "Amigo"   "Inimigo" "Inimigo" "Amigo"
# [1] "Amigo"   "Inimigo" "Inimigo" "Amigo"
# [1] 40 30 30 25
# IGRAPH b57001b DNW- 4 4 --
# + attr: name (v/c), Peso (v/n), TipoAmizade (e/c), weight (e/n)
# + edges from b57001b (vertex names):
# [1] john->ana     lara->vitoria john->lara    john->lara
# IGRAPH b57001b DNWB 4 4 --
# + attr: name (v/c), Peso (v/n), type (v/c), TipoAmizade (e/c), weight
# | (e/n)
# + edges from b57001b (vertex names):
# [1] john->ana     lara->vitoria john->lara    john->lara
# Plot with title “”
