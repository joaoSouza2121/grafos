# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoSouza2121/grafos/blob/main/Matricas_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Métricas

# %%
install.packages("igraph")
library(igraph)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %% [markdown]
# carregamos um grafo de relacionamtos 53 vertices e 179 arestas

# %%
grafo8 = read_graph("Grafo.graphml", format = c("graphml"))

# %%
plot(grafo8)
# Out:
# Plot with title “”

# %%
grafo8
# Out:
# IGRAPH 1f08d40 D-W- 53 179 --
# + attr: label (v/c), r (v/n), g (v/n), b (v/n), x (v/n), y (v/n), size
# | (v/n), Lokationposition1highest53lowest (v/n), Handicapped (v/n),
# | Repeater (v/n), Sweetsgiver (v/n), id (v/c), Edge Label (e/c), weight
# | (e/n), id (e/c)
# + edges from 1f08d40:
#  [1]  1-> 4  1-> 5  1->37  2->15  2->25  2->51  3-> 2  3-> 4  3-> 9  3->16
# [11]  3->36  4->10  4->14  4->23  4->36  4->46  4->49  5-> 1  5-> 6  5->14
# [21]  5->24  6-> 2  6-> 4  6-> 5  6->14  7->11  7->16  9->41  9->50 10-> 4
# [31] 11-> 7 11-> 9 11->14 11->15 11->28 12->44 13->41 14-> 1 14->15 14->23
# [41] 14->46 15-> 5 15-> 6 15-> 7 15->14 15->17 15->23 15->25 15->46 15->51
# + ... omitted several edges

# %% [markdown]
# Grau de entrada e saída

# %%
degree(grafo8, mode="all")
# Out:
#  [1] 11  7  8 10 10  7  5  0  6  2 13  2  2 18 26  8  6  7  2  0  4 13 15  9  8
# [26]  3  2  2  3  7  6  2  4  0  1 13  4 14  5  0 15  4  4  5  9 14  3  0 13  8
# [51]  8  5  5

# %% [markdown]
# Entrada

# %%
degree(grafo8, mode="in")
# Out:
#  [1]  8  4  3  4  6  3  3  0  4  1  8  1  1 14 17  4  5  1  2  0  3  3 11  5  5
# [26]  0  1  1  1  3  1  1  2  0  0  4  2  2  2  0 10  1  0  3  3 10  1  0  4  4
# [51]  5  1  1

# %% [markdown]
# Saída

# %%
degree(grafo8, mode="out")
# Out:
#  [1]  3  3  5  6  4  4  2  0  2  1  5  1  1  4  9  4  1  6  0  0  1 10  4  4  3
# [26]  3  1  1  2  4  5  1  2  0  1  9  2 12  3  0  5  3  4  2  6  4  2  0  9  4
# [51]  3  4  4

# %% [markdown]
# Colocando o grau no tamanho do vértice

# %%
grau  =  degree(grafo8, mode="in")

# %%
plot(grafo8, vertex.size=grau)
# Out:
# Plot with title “”

# %% [markdown]
# Diametro (maior distância entre diferentes vértices)

# %%
diameter(grafo8, directed=T)
# Out:
# [1] 8

# %%
diameter(grafo8, directed=F)
# Out:
# [1] 5

# %% [markdown]
# Vértices que formam o diametro

# %%
get_diameter(grafo8, directed=T)
# Out:
# + 9/53 vertices, from 1f08d40:
# [1]  7 16  3  4 49 38 39 33 27

# %%
get_diameter(grafo8, directed=F)
# Out:
# + 6/53 vertices, from 1f08d40:
# [1] 10  4  6 22 33 27

# %% [markdown]
# Vizinhança, zero incluio o proprio vertice, mode all não considera a direção

# %%
neighborhood(grafo8, 0, mode=c("all"))
# Out:
# [[1]]
# + 1/53 vertex, from 1f08d40:
# [1] 1
#
# [[2]]
# + 1/53 vertex, from 1f08d40:
# [1] 2
#
# [[3]]
# + 1/53 vertex, from 1f08d40:
# [1] 3
#
# [[4]]
# + 1/53 vertex, from 1f08d40:
# [1] 4
#
# [[5]]
# + 1/53 vertex, from 1f08d40:
# [1] 5
#
# [[6]]
# + 1/53 vertex, from 1f08d40:
# [1] 6
#
# [[7]]
# + 1/53 vertex, from 1f08d40:
# [1] 7
#
# [[8]]
# + 1/53 vertex, from 1f08d40:
# [1] 8
#
# [[9]]
# + 1/53 vertex, from 1f08d40:
# [1] 9
#
# [[10]]
# + 1/53 vertex, from 1f08d40:
# [1] 10
#
# [[11]]
# + 1/53 vertex, from 1f08d40:
# [1] 11
#
# [[12]]
# + 1/53 vertex, from 1f08d40:
# [1] 12
#
# [[13]]
# + 1/53 vertex, from 1f08d40:
# [1] 13
#
# [[14]]
# + 1/53 vertex, from 1f08d40:
# [1] 14
#
# [[15]]
# + 1/53 vertex, from 1f08d40:
# [1] 15
#
# [[16]]
# + 1/53 vertex, from 1f08d40:
# [1] 16
#
# [[17]]
# + 1/53 vertex, from 1f08d40:
# [1] 17
#
# [[18]]
# + 1/53 vertex, from 1f08d40:
# [1] 18
#
# [[19]]
# + 1/53 vertex, from 1f08d40:
# [1] 19
#
# [[20]]
# + 1/53 vertex, from 1f08d40:
# [1] 20
#
# [[21]]
# + 1/53 vertex, from 1f08d40:
# [1] 21
#
# [[22]]
# + 1/53 vertex, from 1f08d40:
# [1] 22
#
# [[23]]
# + 1/53 vertex, from 1f08d40:
# [1] 23
#
# [[24]]
# + 1/53 vertex, from 1f08d40:
# [1] 24
#
# [[25]]
# + 1/53 vertex, from 1f08d40:
# [1] 25
#
# [[26]]
# + 1/53 vertex, from 1f08d40:
# [1] 26
#
# [[27]]
# + 1/53 vertex, from 1f08d40:
# [1] 27
#
# [[28]]
# + 1/53 vertex, from 1f08d40:
# [1] 28
#
# [[29]]
# + 1/53 vertex, from 1f08d40:
# [1] 29
#
# [[30]]
# + 1/53 vertex, from 1f08d40:
# [1] 30
#
# [[31]]
# + 1/53 vertex, from 1f08d40:
# [1] 31
#
# [[32]]
# + 1/53 vertex, from 1f08d40:
# [1] 32
#
# [[33]]
# + 1/53 vertex, from 1f08d40:
# [1] 33
#
# [[34]]
# + 1/53 vertex, from 1f08d40:
# [1] 34
#
# [[35]]
# + 1/53 vertex, from 1f08d40:
# [1] 35
#
# [[36]]
# + 1/53 vertex, from 1f08d40:
# [1] 36
#
# [[37]]
# + 1/53 vertex, from 1f08d40:
# [1] 37
#
# [[38]]
# + 1/53 vertex, from 1f08d40:
# [1] 38
#
# [[39]]
# + 1/53 vertex, from 1f08d40:
# [1] 39
#
# [[40]]
# + 1/53 vertex, from 1f08d40:
# [1] 40
#
# [[41]]
# + 1/53 vertex, from 1f08d40:
# [1] 41
#
# [[42]]
# + 1/53 vertex, from 1f08d40:
# [1] 42
#
# [[43]]
# + 1/53 vertex, from 1f08d40:
# [1] 43
#
# [[44]]
# + 1/53 vertex, from 1f08d40:
# [1] 44
#
# [[45]]
# + 1/53 vertex, from 1f08d40:
# [1] 45
#
# [[46]]
# + 1/53 vertex, from 1f08d40:
# [1] 46
#
# [[47]]
# + 1/53 vertex, from 1f08d40:
# [1] 47
#
# [[48]]
# + 1/53 vertex, from 1f08d40:
# [1] 48
#
# [[49]]
# + 1/53 vertex, from 1f08d40:
# [1] 49
#
# [[50]]
# + 1/53 vertex, from 1f08d40:
# [1] 50
#
# [[51]]
# + 1/53 vertex, from 1f08d40:
# [1] 51
#
# [[52]]
# + 1/53 vertex, from 1f08d40:
# [1] 52
#
# [[53]]
# + 1/53 vertex, from 1f08d40:
# [1] 53

# %% [markdown]
# Densidade do grafo

# %%
edge_density(grafo8)
# Out:
# [1] 0.0649492

# %% [markdown]
# Teste de isomorfismo

# %%
grafo9 = grafo8
isomorphic(grafo8,grafo9)
# Out:
# [1] TRUE
